# %% [markdown]
# <a href="https://colab.research.google.com/github/vishal-burman/PyTorch-Architectures/blob/master/misc/Clustering_Engine_For_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install -qU transformers sentence-transformers
# Out:
#      |████████████████████████████████| 5.3 MB 5.8 MB/s
#      |████████████████████████████████| 85 kB 2.0 MB/s
#      |████████████████████████████████| 7.6 MB 26.8 MB/s
#      |████████████████████████████████| 163 kB 39.4 MB/s
#      |████████████████████████████████| 1.3 MB 52.9 MB/s
# ...

# %%
import random
from typing import List
from sentence_transformers import SentenceTransformer

# %%
sentence_encoder_name = "all-MiniLM-L12-v2"
sentence_encoder = SentenceTransformer(sentence_encoder_name)
# Out:
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/573 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/134M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/352 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
def split_into_windows(sentences: List[str], window_size: int):
  pass

# %%
def read_file(filename: str, verbose: bool = False):
  """
  filename (str): A readable file containing separate text on separate line
  """
  lines = open(filename, "r").read().splitlines()
  if verbose:  
    print(f"---------------------------------------")
    print(f"Some random sentences:\n")
    print(*random.sample(lines, 5), sep="\n\n")
    print(f"---------------------------------------")
  return lines

# %%
filename = f"your-filename"
sentences = read_file(filename)
print(f"Total sentences: {len(sentences)}")
# Out:
# Total sentences: 119873
